# %%
import seaborn as sn
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

# matplotlib.use("pgf")
# matplotlib.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
# })

# %%
# Using seaborn's style
plt.style.use('seaborn')

# With LaTex fonts
# plt.style.use('tex')

# %%
array = [
    [0.51, 0.39, 0.02, 0.00, 0.05, 0.03, 0.01], 
    [0.08, 0.72, 0.04, 0.04, 0.00, 0.08, 0.04], 
    [0.00, 0.68, 0.24, 0.08, 0.00, 0.00, 0.00], 
    [0.02, 0.06, 0.03, 0.82, 0.05, 0.02, 0.00],
    [0.00, 0.17, 0.10, 0.25, 0.35, 0.12, 0.00], 
    [0.00, 0.03, 0.00, 0.13, 0.01, 0.83, 0.00], 
    [0.34, 0.22, 0.00, 0.03, 0.01, 0.00, 0.40], 
]

columns = ['standing', 'walking', 'get_down', 'sitting', 'get_up',
          'lying', 'no_person']

df_cm = pd.DataFrame(array, index = columns,
                  columns = columns)

plt.figure(figsize = (10,7))
sn.set(font_scale=1)
sn.heatmap(df_cm, annot=True, cmap="YlGnBu", fmt=".2f", annot_kws={"size": 18}, cbar=False, square=True)

# plt.savefig('histogram.pgf')
# Out:
# <AxesSubplot:>
